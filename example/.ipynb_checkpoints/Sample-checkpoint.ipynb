# %% [markdown]
# # Example Worksheet
# This worksheet was created to show function usability and test cases passes.

# %%
import matplotlib.pyplot as plt
from colourblind8.colourblind8 import Colourblind8
import numpy as np

# %% [markdown]
# ### Testing the function `plot_lines()`

# %%
#Here is the test data set
x=[1,2,4,5]
y_list=[[1,2,3.3,2.2],[2,3,3.5,4],[3,3.6,4.3,4],[4,4.2,5,5.6],[5,5.5,5.2,6.5],[6,7.2,6.1,6.9],[7,8,7.4,8],[8,9,7.8,8.2],[9,9.3,9.6,9.2]]

# %% [markdown]
# #### Testing with the colour palette `deutera`

# %%
cb = Colourblind8()
cb.plot_lines(x=x, y=y_list,alpha =1.0, labels =['a','b','c','d','e','f','g','h','i'], palette = 'deutera', title = "Deutera Line Example", x_lab = "X label" , y_lab = "Y label" , legend_title = "Labels" );

# %% [markdown]
# #### Testing with the colour palette `prota`

# %%
cb = Colourblind8()
cb.plot_lines(x=x, y=y_list,alpha =1.0, labels =['a','b','c','d','e','f','g','h','i'], palette = 'prota', title = "Prota Line Example", x_lab = "X label" , y_lab = "Y label" , legend_title = "Labels" );

# %% [markdown]
# #### Testing with the colour palette `titra`

# %%
cb = Colourblind8()
cb.plot_lines(x=x, y=y_list,alpha =1.0, labels =['a','b','c','d','e','f','g','h','i'], palette = 'trita', title = "Trita Line Example", x_lab = "X label" , y_lab = "Y label" , legend_title = "Labels" );

# %% [markdown]
# ### Testing the function `plot_scatter()`

# %%
#Here is the test data set
N = 10
x = np.random.rand(N )
y_1 = np.random.rand(N)
y_2 = np.random.rand(N)
y_3 = np.random.rand(N)
y_4 = np.random.rand(N)
y_5 = np.random.rand(N)
y_6 = np.random.rand(N)
y_7 = np.random.rand(N)
y_8 = np.random.rand(N)
y_9 = np.random.rand(N)

y_list= []
for i in range(9):
    y = np.random.rand(N)
    y_list.append(y)
# Out:
# [array([0.60571133, 0.32219915, 0.75389737, 0.66284763, 0.97464998,
#        0.69051089, 0.89525322, 0.65279926, 0.86827989, 0.92631929]), array([0.04890319, 0.47472028, 0.7344666 , 0.18613597, 0.81934435,
#        0.30760658, 0.99785182, 0.30528936, 0.71339523, 0.63207517]), array([0.15479727, 0.7100874 , 0.86012676, 0.54593562, 0.10372893,
#        0.90056503, 0.42500582, 0.88236439, 0.07586752, 0.66728432]), array([0.99788923, 0.39521059, 0.60074672, 0.29822482, 0.86248092,
#        0.55266783, 0.22796349, 0.91099327, 0.63946398, 0.99033127]), array([0.07370877, 0.33762334, 0.18593894, 0.21753334, 0.30342072,
#        0.93268308, 0.33335793, 0.7072485 , 0.41980384, 0.35121439]), array([0.24270849, 0.08395748, 0.15320606, 0.11089826, 0.8625841 ,
#        0.71125786, 0.77671171, 0.84128206, 0.23536199, 0.89590362]), array([0.91861174, 0.23465896, 0.83962904, 0.68580202, 0.01247462,
# ...

# %% [markdown]
# #### Testing with the colour palette `deutera`

# %%
cb = Colourblind8()
cb.plot_scatter(x=x, y=y_list,alpha =1.0, labels =['a','b','c','d','e','f','g','h','i'], palette = 'deutera', title = "Deutera Line Example", x_lab = "X label" , y_lab = "Y label" , legend_title = "Labels" );

# %% [markdown]
# #### Testing with the colour palette `prota`

# %% [markdown]
# #### Testing with the colour palette `titra`

# %% [markdown]
# ### Testing the function `plot_histogram()`

# %%
# Test dataset

y_list=[[1,1,2,2,3,4,6,3,4,4,5,],[1,2,2,1,1,1,3,3,2,3,2,3,4],[3,3.6,4.3,4],[4,4.2,5,5.6],[5,5.5,5.2,6.5],[6,7.2,6.1,6.9],[7,8,7.4,8],[8,9,7.8,8.2],[9,9.3,9.6,9.2]]

# %% [markdown]
# #### Testing with the colour palette `deutera`

# %%
cb.plot_histogram(y=y_list,alpha =0.8,bins=4, labels =['a','b','c','d','e','f','g','h','i'], palette = 'deutera', title = "Example Histogram", x_lab = "X" , legend_title = "Labels" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-c69d873cec40> in <module>
# ----> 1 cb.plot_histogram(y=y_list,alpha =0.8,bins=4, labels =['a','b','c','d','e','f','g','h','i'], palette = 'deutera', title = "Example Histogram", x_lab = "X" , legend_title = "Labels" )
#
# TypeError: plot_histogram() got an unexpected keyword argument 'bins'

# %% [markdown]
# #### Testing with the colour palette `prota`

# %% [markdown]
# #### Testing with the colour palette `titra`
